# %%
import os 

path = os.path.join('data/archive/FaceForensics++_C23/coordinates/DeepFakeDetection/01_02_meeting_serious_YYGY8LOK/~~.json')

# %%
cropped_img = os.path.join('data/archive/FaceForensics++_C23/crops/DeepFakeDetection/01_02__meeting_serious__YVGY8LOK/0_0.png')

# %%
os.path.splitext(os.path.basename(cropped_img))[0]
# Out:
# '0_0'

# %%
folder_name = os.path.basename(os.path.dirname(cropped_img))
folder_name
# Out:
# '01_02__meeting_serious__YVGY8LOK'

# %%
os.path.dirname(cropped_img)
# Out:
# 'data/archive/FaceForensics++_C23/crops/DeepFakeDetection/01_02__meeting_serious__YVGY8LOK'

# %%
new_path = r'0_0.json'
os.path.splitext(os.path.basename(new_path))[0]
# Out:
# '0_0'
