# %%
import cv2, config, os

# %%
dfd_path = config.DFD
dfs_path = config.DFS
f2f_path = config.F2F
fsh_path = config.FSH
fsw_path = config.FSW
ntx_path = config.NTX
org_path = config.ORG

# %%
# DeepFakeDetection

sample_lst = os.listdir(dfd_path)
video_name = sample_lst[10]
video_path = os.path.join(dfd_path, video_name)

# 동영상 열기
cap = cv2.VideoCapture(video_path)

# 동영상이 제대로 열렸는지 확인
if not cap.isOpened():
    print("동영상을 열 수 없습니다.")
    exit()

while True:
    ret, frame = cap.read()  # 한 프레임씩 읽기
    if not ret:              # 더 이상 프레임이 없으면 종료
        break

    cv2.imshow("Video", frame)  # 프레임 화면에 표시

    # q 키를 누르면 종료
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# Deepfakes

sample_lst = os.listdir(dfs_path)
video_name = sample_lst[10]
video_path = os.path.join(dfs_path, video_name)

# 동영상 열기
cap = cv2.VideoCapture(video_path)

# 동영상이 제대로 열렸는지 확인
if not cap.isOpened():
    print("동영상을 열 수 없습니다.")
    exit()

while True:
    ret, frame = cap.read()  # 한 프레임씩 읽기
    if not ret:              # 더 이상 프레임이 없으면 종료
        break

    cv2.imshow("Video", frame)  # 프레임 화면에 표시

    # q 키를 누르면 종료
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# Face2Face

sample_lst = os.listdir(f2f_path)
video_name = sample_lst[10]
video_path = os.path.join(f2f_path, video_name)

# 동영상 열기
cap = cv2.VideoCapture(video_path)

# 동영상이 제대로 열렸는지 확인
if not cap.isOpened():
    print("동영상을 열 수 없습니다.")
    exit()

while True:
    ret, frame = cap.read()  # 한 프레임씩 읽기
    if not ret:              # 더 이상 프레임이 없으면 종료
        break

    cv2.imshow("Video", frame)  # 프레임 화면에 표시

    # q 키를 누르면 종료
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# FaceShifter

sample_lst = os.listdir(fsh_path)
video_name = sample_lst[10]
video_path = os.path.join(fsh_path, video_name)

# 동영상 열기
cap = cv2.VideoCapture(video_path)

# 동영상이 제대로 열렸는지 확인
if not cap.isOpened():
    print("동영상을 열 수 없습니다.")
    exit()

while True:
    ret, frame = cap.read()  # 한 프레임씩 읽기
    if not ret:              # 더 이상 프레임이 없으면 종료
        break

    cv2.imshow("Video", frame)  # 프레임 화면에 표시

    # q 키를 누르면 종료
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# FaceSwap

sample_lst = os.listdir(fsw_path)
video_name = sample_lst[10]
video_path = os.path.join(fsw_path, video_name)

# 동영상 열기
cap = cv2.VideoCapture(video_path)

# 동영상이 제대로 열렸는지 확인
if not cap.isOpened():
    print("동영상을 열 수 없습니다.")
    exit()

while True:
    ret, frame = cap.read()  # 한 프레임씩 읽기
    if not ret:              # 더 이상 프레임이 없으면 종료
        break

    cv2.imshow("Video", frame)  # 프레임 화면에 표시

    # q 키를 누르면 종료
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# NeuralTextures

sample_lst = os.listdir(ntx_path)
video_name = sample_lst[10]
video_path = os.path.join(ntx_path, video_name)

# 동영상 열기
cap = cv2.VideoCapture(video_path)

# 동영상이 제대로 열렸는지 확인
if not cap.isOpened():
    print("동영상을 열 수 없습니다.")
    exit()

while True:
    ret, frame = cap.read()  # 한 프레임씩 읽기
    if not ret:              # 더 이상 프레임이 없으면 종료
        break

    cv2.imshow("Video", frame)  # 프레임 화면에 표시

    # q 키를 누르면 종료
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# Original

sample_lst = os.listdir(org_path)
video_name = sample_lst[10]
video_path = os.path.join(org_path, video_name)

# 동영상 열기
cap = cv2.VideoCapture(video_path)

# 동영상이 제대로 열렸는지 확인
if not cap.isOpened():
    print("동영상을 열 수 없습니다.")
    exit()

while True:
    ret, frame = cap.read()  # 한 프레임씩 읽기
    if not ret:              # 더 이상 프레임이 없으면 종료
        break

    cv2.imshow("Video", frame)  # 프레임 화면에 표시

    # q 키를 누르면 종료
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
