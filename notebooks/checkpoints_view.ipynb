# %%
import torch, config, os

CHECKPOINTS_DIR = os.path.join(config.ROOT_DIR, 'checkpoints', 'checkpoints_v2')

# %%
best = torch.load(os.path.join(CHECKPOINTS_DIR, 'best_model_All.pth'))

# %%
best.keys()
# Out:
# dict_keys(['epoch', 'model_state_dict', 'optimizer_state_dict', 'scheduler_state_dict', 'history', 'config', 'dataset'])

# %%
best['history']
# Out:
# {'train_loss': [0.6881183451814804, 0.671747170651745],
#  'train_accuracy': [0.5013955081765695, 0.5063729886041896],
#  'val_loss': [0.681654621696257, 0.6541402507489301],
#  'val_accuracy': [0.5336800096746886, 0.5168702382392066],
#  'train_positive': [49414, 49326],
#  'train_negative': [49833, 49921],
#  'val_positive': [24807, 9712],
#  'val_negative': [0, 15095]}

# %%
epoch_5 = torch.load(os.path.join(CHECKPOINTS_DIR, 'checkpoint_epoch5_All.pth'))
epoch_5['history']
# Out:
# {'train_loss': [0.6881183451814804,
#   0.671747170651745,
#   0.6694235021734015,
#   0.6680156250749887,
#   0.6673715317775871,
#   0.6667422975010974],
#  'train_accuracy': [0.5013955081765695,
#   0.5063729886041896,
#   0.5074813344483964,
#   0.5106149304261086,
#   0.5116426692998277,
#   0.5131540499964734],
#  'val_loss': [0.681654621696257,
#   0.6541402507489301,
#   0.7236530373820483,
#   0.6640400030319342,
#   0.7423288030135562,
#   0.7068884680726157],
#  'val_accuracy': [0.5336800096746886,
#   0.5168702382392066,
#   0.5318256943604628,
#   0.5090901761599549,
#   0.5313419599306647,
#   0.532591607207643],
#  'train_positive': [49414, 49326, 49542, 49639, 49085, 48987],
#  'train_negative': [49833, 49921, 49705, 49608, 50162, 50260],
#  'val_positive': [24807, 9712, 24239, 6631, 23591, 23890],
#  'val_negative': [0, 15095, 568, 18176, 1216, 917]}
